# %%
df=pd.read_csv("IMDB-Movie-Data.csv")

# %%
import pandas as pd
import numpy as np

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
type(df['Title'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
new_df.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
new_df['Votes'][2]="hggh" #change thee datatypes
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_9340\387700644.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Votes'][2]="hggh"

# %%
new_df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
new_df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
new_df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
new_df.to_numpy()
# Out:
# array([[1, 'Guardians of the Galaxy', 'Action,Adventure,Sci-Fi', ...,
#         757074, 333.13, 76.0],
#        [2, 'Prometheus', 'Adventure,Mystery,Sci-Fi', ..., 485820, 126.46,
#         65.0],
#        [3, 'Split', 'Horror,Thriller', ..., 'hggh', 138.12, 62.0],
#        ...,
#        [998, 'Step Up 2: The Streets', 'Drama,Music,Romance', ..., 70699,
#         58.01, 50.0],
#        [999, 'Search Party', 'Adventure,Comedy', ..., 4881, nan, 22.0],
#        [1000, 'Nine Lives', 'Comedy,Family,Fantasy', ..., 12435, 19.64,
#         11.0]], dtype=object)

# %%
new_df.T
# Out:
#                                                                   0    \
# Rank                                                                1
# Title                                         Guardians of the Galaxy
# Genre                                         Action,Adventure,Sci-Fi
# Description         A group of intergalactic criminals are forced ...
# Director                                                   James Gunn
# Actors              Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Year                                                             2014
# Runtime (Minutes)                                                 121
# Rating                                                            8.1
# Votes                                                          757074
# Revenue (Millions)                                             333.13
# Metascore                                                        76.0
#
# ...

# %%
new_df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
new_df.sort_index(axis=0,ascending=False)
# Out:
#                                                      App             Category  \
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10838                             Parkinson Exercices FR              MEDICAL
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# ...                                                  ...                  ...
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
#
# ...

# %%
new_df.sort_index(axis=1,ascending=False)
# Out:
#        Type                Size Reviews  Rating Price      Last Updated  \
# 0      Free                 19M     159     4.1     0   January 7, 2018
# 1      Free                 14M     967     3.9     0  January 15, 2018
# 2      Free                8.7M   87510     4.7     0    August 1, 2018
# 3      Free                 25M  215644     4.5     0      June 8, 2018
# 4      Free                2.8M     967     4.3     0     June 20, 2018
# ...     ...                 ...     ...     ...   ...               ...
# 10836  Free                 53M      38     4.5     0     July 25, 2017
# 10837  Free                3.6M       4     5.0     0      July 6, 2018
# 10838  Free                9.5M       3     NaN     0  January 20, 2017
# 10839  Free  Varies with device     114     4.5     0  January 19, 2015
# 10840  Free                 19M  398307     4.5     0     July 25, 2018
#
#           Installs                     Genres         Current Ver  \
# ...

# %%
new_df.loc[(new_df["Installs"]>2015)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 new_df.loc[(new_df["Installs"]>2015)]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:58, in OpsMixin.__gt__(self, other)
#      56 @unpack_zerodim_and_defer("__gt__")
#      57 def __gt__(self, other):
# ---> 58     return self._cmp_method(other, operator.gt)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:6243, in Series._cmp_method(self, other, op)
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# ...

# %%
new_df["Rank"]
# Out:
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
#        ...
# 995     996
# 996     997
# 997     998
# 998     999
# 999    1000
# Name: Rank, Length: 1000, dtype: int64

# %%
new_df.loc[(new_df["Rank"]>5) & (new_df["year"]<2015)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# ...

# %%
new_df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
new_df.loc[(new_df["Genre"]=="Horror")]
# Out:
#      Rank                                 Title   Genre  \
# 42     43               Don't Fuck in the Woods  Horror
# 258   259                            Lights Out  Horror
# 269   270                               Satanic  Horror
# 302   303                The Cabin in the Woods  Horror
# 401   402                        The Black Room  Horror
# 623   624                       Friday the 13th  Horror
# 675   676                              The Mist  Horror
# 858   859                   The Hills Have Eyes  Horror
# 936   937  The Human Centipede (First Sequence)  Horror
# 988   989                               Martyrs  Horror
# 996   997                       Hostel: Part II  Horror
#
#                                            Description           Director  \
# 42   A group of friends are going on a camping trip...      Shawn Burkett
# 258  Rebecca must unlock the terror behind her litt...  David F. Sandberg
# ...

# %%
new_df["Genre"]
# Out:
# 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 995         Crime,Drama,Mystery
# 996                      Horror
# 997         Drama,Music,Romance
# 998            Adventure,Comedy
# 999       Comedy,Family,Fantasy
# Name: Genre, Length: 1000, dtype: object

# %% [markdown]
# # you see that in this we add 4 condition
# new_df.loc[(new_df["Genre"]=="Horror") & (new_df["Rating"]>5)& (new_df["Year"]>2008)&(new_df["Metascore"]>58)]
# #condition in one code use only 1 loc
# #condition 2 naav ghevun jyabhi column madhal je bhi kadhyachy aahe te aika ( madhe asaall pahije)
# # you can add multiple & condition inabove example we use 4  & you can use multiple

# %%
new_df.loc[(new_df["Genre"]=="Horror") & (new_df["Rating"]>5)& (new_df["Year"]>2008)&(new_df["Metascore"]>58)]
# Out:
#      Rank                   Title   Genre  \
# 302   303  The Cabin in the Woods  Horror
#
#                                            Description      Director  \
# 302  Five friends go for a break at a remote cabin,...  Drew Goddard
#
#                                                 Actors  Year  \
# 302  Kristen Connolly, Chris Hemsworth, Anna Hutchi...  2012
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 302                 95     7.0  295554               42.04       72.0

# %%
new_df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
new_df.loc[(new_df["Rank"]>5)& (new_df["Year"]>2012)&(new_df["Rating"]>7) &(new_df["Votes"]>2300)&(new_df["Metascore"]>60)
           &(new_df["Director"]=="David Yates")]
# Out:
#     Rank                                    Title                     Genre  \
# 10    11  Fantastic Beasts and Where to Find Them  Adventure,Family,Fantasy
#
#                                           Description     Director  \
# 10  The adventures of writer Newt Scamander in New...  David Yates
#
#                                                Actors  Year  \
# 10  Eddie Redmayne, Katherine Waterston, Alison Su...  2016
#
#     Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 10                133     7.5  232072              234.02       66.0

# %%
a=new_df.loc[(new_df["Genre"]=="Horror")& (new_df["Year"]>2002)&(new_df["Rating"]>5)&(new_df["Votes"]>63785)
           &(new_df["Metascore"]>50)& (new_df["Rank"]>600)&(new_df["Director"]=="Alexandre Aja")]#7 condition we applied

# %%
a.to_csv("filter.csv")

# %%
new_df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
new_df.loc[(new_df["Genre"]=="Horror")]
# Out:
#      Rank                                 Title   Genre  \
# 42     43               Don't Fuck in the Woods  Horror
# 258   259                            Lights Out  Horror
# 269   270                               Satanic  Horror
# 302   303                The Cabin in the Woods  Horror
# 401   402                        The Black Room  Horror
# 623   624                       Friday the 13th  Horror
# 675   676                              The Mist  Horror
# 858   859                   The Hills Have Eyes  Horror
# 936   937  The Human Centipede (First Sequence)  Horror
# 988   989                               Martyrs  Horror
# 996   997                       Hostel: Part II  Horror
#
#                                            Description           Director  \
# 42   A group of friends are going on a camping trip...      Shawn Burkett
# 258  Rebecca must unlock the terror behind her litt...  David F. Sandberg
# ...

# %%
data=pd.read_csv("Play Store Data (1).csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
data.loc[(data["App"]=="Sya9a Maroc - FR")]
# Out:
#                     App Category  Rating Reviews Size Installs  Type Price  \
# 10836  Sya9a Maroc - FR   FAMILY     4.5      38  53M   5,000+  Free     0
#
#       Content Rating     Genres   Last Updated Current Ver Android Ver
# 10836       Everyone  Education  July 25, 2017        1.48  4.1 and up

# %%
data.drop([10836]) #drop the row by giving index number
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                           FR Forms             BUSINESS
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
data.sort_index(ascending=False)
# Out:
#                                                      App             Category  \
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10838                             Parkinson Exercices FR              MEDICAL
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# ...                                                  ...                  ...
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
#
# ...

# %%
data.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data.transpose
# Out:
# <bound method DataFrame.transpose of                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
# ...

# %% [markdown]
# # FILTEROUT THE BIGDATASET AND FIND REQUIRD DATA THAT WE WANT AND SORT INDEX AND ASSIGN VAIRABLE AND CONVERT IN CSV FORMAT

# %%
solve=new_df.loc[(new_df["Rank"]>5)& (new_df["Year"]>2012)&(new_df["Rating"]>7) &(new_df["Votes"]>2300)&(new_df["Metascore"]>60)
           ] #in we can see that we filter the dataset find requirs data ansign variable solve

# %%
solve.reset_index(drop=True) # in this we provide new idex to that data set i e solve
# Out:
#      Rank                                    Title  \
# 0       7                               La La Land
# 1       9                       The Lost City of Z
# 2      11  Fantastic Beasts and Where to Find Them
# 3      12                           Hidden Figures
# 4      13                                Rogue One
# ..    ...                                      ...
# 143   916                                  Goksung
# 144   939                  The Siege of Jadotville
# 145   951           Me and Earl and the Dying Girl
# 146   954                      The Kings of Summer
# 147   975                           Queen of Katwe
#
#                           Genre  \
# 0            Comedy,Drama,Music
# 1    Action,Adventure,Biography
# 2      Adventure,Family,Fantasy
# 3       Biography,Drama,History
# 4       Action,Adventure,Sci-Fi
# ..                          ...
# 143        Drama,Fantasy,Horror
# 144       Action,Drama,Thriller
# 145                Comedy,Drama
# ...

# %%
solve.to_csv("solvedd.csv") #in this line we assign that dataset to csv format and we can read it on excel file

# %%
a=10
b=20
def change():
     global b
     a=45
     b=56
change()
print(a)
print(b)
# Out:
# 10
# 56
